# %%
import sys
import importlib
from fpdf import FPDF
import pandas as pd
import numpy as np

dir_scr = "../utils/"
sys.path.append(dir_scr)

import mypdfutils
importlib.reload(mypdfutils)


from fpdf import FPDF

class PDF(FPDF):
    def __init__(self, font="Arial", font_size=12):
        super().__init__()

        # Page dimensions (A4 size by default)
        self.w = 210
        self.h = 297
        self.default_font = font
        self.default_font_size = font_size

        # Set the default margins
        self.left_margin = 10
        self.top_margin = 10
        self.right_margin = 10
        self.bottom_margin = 10

        self.gray_color = (128, 128, 128)
        self.black_color = (0, 0, 0)

        self.box_width = 20
        self.min_box_width = 30
        self.box_height = 5
        self.box_spacing = 17

    def set_default_font(self):
        self.set_font(self.default_font, size=self.default_font_size)

    def set_small_font(self):
        self.set_font(self.default_font, size=8)

    def set_small_font_bold(self):
        self.set_font(self.default_font, size=8, style="B")

    def center_text(self, text, font=None, size=None, bold=False, custom_height=None, px=0):
        # Use the default font and size if not provided
        font = font or self.default_font
        size = size or self.default_font_size

        # Set font and size
        if bold:
            self.set_font(font, style="B", size=size)
        else:
            self.set_font(font, size=size)

        # Get the width and height of the text
        text_width = self.get_string_width(text)
        text_height = self.font_size

        # Use custom height if provided, otherwise use the vertical center of the page
        if custom_height is not None:
            y = custom_height - text_height / 2
        else:
            y = (self.h - text_height) / 2

        # Set margins before writing the text
        self.set_left_margin(self.left_margin)
        self.set_top_margin(self.top_margin)
        self.set_right_margin(self.right_margin)
        self.set_auto_page_break(auto=True, margin=self.bottom_margin)

        # Write the text at the calculated position
        self.text((self.w - text_width) / 2 + px, y, text)

    def footer(self):
        return
        # self.set_y(-15)
        # self.set_font('Helvetica', 'I', 8)
        # self.set_text_color(128)
        # self.cell(0, 10, 'Page ' + str(self.page_no()), 0, 0, 'C')

    def header(self):
        pdf.image("/home/nic/al/commissaire/resources/headerDocumenti.png", 2, 7, self.w)

    def add_box(self, x, y, text):
        self.set_fill_color(255, 255, 255)
        self.rect(x, y, self.box_width, self.box_height, "DF")
        self.set_text_color(*self.black_color)
        self.set_xy(x, y)
        self.cell(self.box_width, self.box_height, text, 0, 0, "C")

    def add_gray_text(self, x, y, text):
        self.set_text_color(*self.gray_color)
        self.set_xy(x, y)
        self.cell(self.box_width, self.box_height, text, 0, 0, "C")

    def create_boxes(self, x=20, y=40, data=["Pista", "167754", "07", "Q", "0345"]):
        titles = ["Tipo gara", "N° Gara", "Cod. Reg.", "Cin", "Cod. Soc."]


        for i in range(5):
            self.set_small_font()
            self.add_gray_text(x, y - 5, titles[i])
            self.set_small_font_bold()
            self.add_box(x, y, data[i])
            x += self.box_width + self.box_spacing


# Create PDF
pdf = PDF()
pdf.add_page()

# pdf.center_text("CAMPIONATI ITALIANI GIOVANILI SU PISTA", custom_height=22, size=14, bold=1, px=2)
# pdf.center_text("Velodromo di Forlì (FC), 1-4 Agosto 2023", custom_height=28, size=12, bold=1, px=2)

pdf.center_text("FEDERAZIONE CICLISTICA ITALIANA", custom_height=25, size=15, bold=1, px=2)
pdf.create_boxes(x=20, y=38)

# pdf.center_text("ORDINE D'ARRIVO", custom_height=58, size=15, bold=1)
# pdf.center_text("Ordre d'Arrivée", custom_height=65, size=13, bold=1)

pdf.center_text("ELENCO ISCRITTI - Tutti", custom_height=60, size=15, bold=1)
pdf.center_text("Campionati Italiani Pista 2023 - Giovanili", custom_height=67, size=13, bold=1)
pdf.center_text("Velodromo Glauco Servadei - ASD Consorzio delle Soc. Ciclist. Romagnole", custom_height=74, size=12, bold=0)



dir_data = "../../data/Iscritti_167754.xls"
df = pd.read_excel(dir_data)
team        = df["NomeSocieta"].str.lstrip().unique()
idGara      = df["IdGara"][0]
nomeGara    = df["NomeGara"][0]

df.drop(columns=['IdGara', 'NomeGara', 'Nazionalità', 'CodiceFiscale', 'Sesso', 'Riserva', 'Scadenza Certificato'], inplace=True)
nome = np.array(df["NomeTesserato"])
prov = np.array(df["Provincia"]).astype(str)
cat = np.array(df["Categoria"])

df["NomeTesserato"] = [f"{a:s} ({b:s}) [{c:s}]" for (a,b,c) in zip(nome, prov, cat)]

# df = df[df["Categoria"]=="AL"]

df = df.sort_values(by="DorsaleNumero",ignore_index=True)


################ TABLE
table = df[["DorsaleNumero", "CodiceUci", "CodiceFCI", "NomeTesserato", "NomeSocieta"]]
N     = len(table)
ord   = np.arange(1,N+1)
new_column_names = {
    'DorsaleNumero': 'Dors',
    'CodiceUci': 'UCI Id',
    'CodiceFCI': 'Licenza',
    'NomeTesserato': 'Cognome Nome',
    'NomeSocieta': 'Società',
}
table.rename(columns=new_column_names, inplace=True)
table.insert(0, "Ord", ord)




# Full table
pdf.set_font(pdf.default_font, size=9)
col_width = [10,10,25,17,60,60]
col_al    = ["C","C","C","C","L","L"]
ccol_width = np.cumsum(col_width)
row_height = 6
max_page = 40
max_page0 = 30
pagen = 0

x_table, y_table = 15, 80
x,y=x_table,y_table

pdf.set_draw_color(140, 140, 140)

def render_header(y):
    pdf.set_small_font_bold()
    header_content = list(table.keys())
    for j, header in enumerate(header_content):
        pdf.set_xy(x + ccol_width[j - 1] if j > 0 else x_table, y_table)
        pdf.cell(col_width[j], row_height, header, border=1, ln=0, align="C", fill=True)
    y += row_height
    pdf.set_small_font()
    return y


for i, row in table.iterrows():
    if i == 0:
        x,y = 15, 80
        y = render_header(y)

    elif ((pagen==0) and ((i%max_page0)==0)) or ((pagen>0) and (((i-max_page0)%max_page)==0)):
        # New page or the beginning of a new page, render the header

        pdf.add_page()
        x,y = 15, 35
        x_table, y_table = x,y
        y= render_header(y)
        pagen+=1

    if i % 2 == 0:
        pdf.set_fill_color(240, 245, 245)
    else:
        pdf.set_fill_color(255, 255, 255)

    for j, value in enumerate(row):
        if list(table.keys())[j] == "Dors":
            pdf.set_small_font_bold()
        else:
            pdf.set_small_font()

        pdf.set_xy(x + ccol_width[j - 1] if j > 0 else x_table, y)
        pdf.cell(col_width[j], row_height, str(value), border=1, ln=0, align=col_al[j], fill=True)
    y += row_height


pdf.output("test.pdf", 'F')
# Out:
# /tmp/ipykernel_23235/822696913.py:161: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   table.rename(columns=new_column_names, inplace=True)
# ''

# %%
[12,13,4556]
# Out:
#      DorsaleNumero                      NomeTesserato CodiceFCI Categoria  \
# 0                1           ZANNONI SERENA (RE) [DA]   A091111        DA
# 1                1          PIGNATO MARTINA (RA) [ED]   A072439        ED
# 2                1            TASSI EDOARDO (MO) [AL]   A015476        AL
# 3                1          BERARDI MICHELE (RN) [ES]   A073638        ES
# 4                2          CASUBOLO GIULIA (RE) [DA]   A154905        DA
# ..             ...                                ...       ...       ...
# 253             98       MAGAGNOTTI ALESSIO (TN) [AL]   A058753        AL
# 254             99  CARESIA EDOARDO AUGUSTO (TN) [AL]   A125059        AL
# 255            100            LEONI DANIELE (BZ) [AL]   A100050        AL
# 256            101          GOTTARDI MANUEL (BZ) [AL]   A124077        AL
# 257            102        FRACCHETTI DAVIDE (BZ) [AL]   A180982        AL
#
#        CodiceUci DataNascita                     NomeSocieta CodiceSocieta  \
# 0    10033988376  03/10/2008    XPC BELTRAMI TSA COOPERATORI       07F0103
# 1    10054916229  25/11/2010                    BICIFESTIVAL       07N1350
# 2    10031073528  18/07/2008    V.C. PONTENURE 1957-F. ZEPPI       07D0051
# 3    10032974223  05/10/2009          ASD G. C. FAUSTO COPPI       07B0164
# 4    10081929113  21/07/2008    XPC BELTRAMI TSA COOPERATORI       07F0103
# ..           ...         ...                             ...           ...
# 253  10032407276  27/01/2007             C.C. FORTI E VELOCI       20L0001
# 254  10059983669  08/03/2007             C.C. FORTI E VELOCI       20L0001
# 255  10034595133  08/02/2008  LIBERTAS RAIFFEISEN LAIVES ASD       21W0011
# 256  10059334476  03/12/2008  G.S. ALTO ADIGE - SÜDTIROLPOST       21Y0037
# 257  10094358449  02/06/2008  G.S. ALTO ADIGE - SÜDTIROLPOST       21Y0037
#
#                        Note     Cognome             Nome Provincia
# 0            Iscrizione CR.     ZANNONI           SERENA        RE
# 1            Iscrizione CR.     PIGNATO          MARTINA        RA
# 2            Iscrizione CR.       TASSI          EDOARDO        MO
# 3            Iscrizione CR.     BERARDI          MICHELE        RN
# 4            Iscrizione CR.    CASUBOLO           GIULIA        RE
# ..                      ...         ...              ...       ...
# 253   Iscrizione CR. TRENTO  MAGAGNOTTI          ALESSIO        TN
# 254   Iscrizione CR. TRENTO     CARESIA  EDOARDO AUGUSTO        TN
# 255  Iscrizione CR. Bolzano       LEONI          DANIELE        BZ
# 256  Iscrizione CR. Bolzano    GOTTARDI           MANUEL        BZ
# 257          Iscrizione CR.  FRACCHETTI           DAVIDE        BZ
#
# [258 rows x 12 columns]

# %%
df.keys()
# Out:
# Index(['DorsaleNumero', 'NomeTesserato', 'CodiceFCI', 'Categoria', 'CodiceUci',
#        'DataNascita', 'NomeSocieta', 'CodiceSocieta', 'Note', 'Cognome',
#        'Nome', 'Provincia'],
#       dtype='object')

# %%
table[0][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_23235/3235807842.py in <module>
# ----> 1 table[0][0]
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
reg_cod = df["Provincia"]

reg_
# Out:
# 0      RA
# 1      RA
# 2      RA
# 3      PD
# 4      PD
#        ..
# 253    RE
# 254    RE
# 255    FI
# 256    LI
# 257    FI
# Name: Provincia, Length: 258, dtype: object

# %%
df["Provincia"]
# Out:
# 0      RA
# 1      RA
# 2      RA
# 3      PD
# 4      PD
#        ..
# 253    RE
# 254    RE
# 255    FI
# 256    LI
# 257    FI
# Name: Provincia, Length: 258, dtype: object

# %%
# Out:
# ['CONTI MARTINA (RA)',
#  'DONATI FLAVIO (RA)',
#  'SIGNORINI LUCA (RA)',
#  'CECCARELLO LORENZO (PD)',
#  'QUAGLIO CHRISTIAN (PD)',
#  'CAPUZZO MARCO (PD)',
#  'ROS FEDERICO (PN)',
#  'TABOGA GIOELE (UD)',
#  'DALLE CRODE LORENZO (GO)',
#  'PITTA JACOPO (UD)',
#  'ROVERETTO SIMONE (UD)',
#  'MORETTI ANDREA (PN)',
#  'CAPORASO CHIARA (SA)',
#  'CARRAFIELLO RICCARDO (SA)',
#  'MAZZONI MIRCO (TO)',
#  'NADALI AURORA (VR)',
#  'MELOTTO FILIPPO (VR)',
#  'SCAPINI LUCIA (VR)',
#  'ROSSIGNOLI MATILDE (VR)',
#  'MELOTTO THOMAS (VR)',
#  'FERRARI IRENE (MN)',
#  'ACUTI MARIA (MN)',
#  'ELIOTROPIO FILIPPI SOFIA (TP)',
#  'CRUCIATA STEFANO (TP)',
#  'BORELLA LORENZO (VE)',
#  'FORLIN DANIELE (PD)',
#  "NIERI NICCOLO' (PO)",
#  'FERRUZZI EMANUELE (FI)',
#  'MORONI GABRIELE (FI)',
#  'VEGLIA ALBERTO (CN)',
#  'SBRAVATI ALICE (VR)',
#  "SCAMPERLE NICOLO' (VR)",
#  'MORELLO GAIA (VI)',
#  'SANTELLA GIULIA (MN)',
#  'BORDIGNON SILVIA (VI)',
#  'OSPIZIO EDOARDO (VR)',
#  'BERARDI MICHELE (RN)',
#  'BRAMINI GORETTI GIORGIO (PG)',
#  'LO PICCOLO DOMENICO (PA)',
#  "GALLI' LUCREZIA (PA)",
#  'TRABUCCHI BEATRICE (PC)',
#  'BARTOLOTTA DANIEL (RG)',
#  'NERVO GIORGIA (TN)',
#  'CIAGHI SILVIA (TN)',
#  'AMISTADI ANNA (TN)',
#  'CARRARA TARARA RAFFAELE (PG)',
#  'MUSTA LEANDRO (PG)',
#  'BATTISTELLI PIETRO (PG)',
#  "D'AGNESE ELENA (GO)",
#  'VISINTIN EMMA (GO)',
#  'BARATTIN PIERA (PN)',
#  'DEOTTO ELEONORA (PN)',
#  "MARZINOTTO NICOLO' (PN)",
#  'MONI BIDIN GIACOMO (PN)',
#  'PIGHIN CHRISTIAN (PN)',
#  'PIGNATO MARTINA (RA)',
#  'VANUZZO ASIA (RA)',
#  'BULDRINI MARGOT (RN)',
#  'CASTELLI TEODORA (RA)',
#  'VANUZZO EMMA (RA)',
#  'BANI DESIREE (BS)',
#  'BIANCHI ERJA GIULIA (VA)',
#  'MARCHI TOMMASO (TV)',
#  'LANARO EMMA (VI)',
#  'SILO GIADA (VI)',
#  'LAZZARIN ELLIS (VA)',
#  'MAGAGNOTTI ERIK (TN)',
#  'CARLIN GIACOMO (TN)',
#  'IDRIZI MELSAN (TN)',
#  'SANDRI OSCAR VLAD (TN)',
#  'MAGAGNOTTI ALESSIO (TN)',
#  'CARESIA EDOARDO AUGUSTO (TN)',
#  'SAMBI JOLANDA (RA)',
#  'FRANCESCHINI GIULIA (FE)',
#  'LODA MARCO (BS)',
#  'MORETTI MATTIA (TO)',
#  'BACCI GINEVRA (FI)',
#  'SIMEONI MADDALENA (FI)',
#  'PEGOLO CHANTAL (PN)',
#  'GALANTE ARIANNA (TN)',
#  'CAMPANA AGATA (TN)',
#  'BENUZZI LAURA ANNA (TN)',
#  'LAGHI CLARISSA (TN)',
#  'PIFFER MARTA (TN)',
#  'MAGISTRELLI ALESSANDRO (MI)',
#  'GALLO FILIPPO (TO)',
#  'CASSIN JULIAN ANNA (BZ)',
#  'GOTTARDI MANUEL (BZ)',
#  'FRACCHETTI DAVIDE (BZ)',
#  'BOSONIN MELANIE (AO)',
#  'ROCCIA MANUEL (TO)',
#  'COLOMBO AURORA (TO)',
#  'FISCARELLI REBECCA (TO)',
#  'CUAZ CHANTAL (AO)',
#  'CARRETTA MATILDE (TV)',
#  'LUISOTTO BIANCA (TV)',
#  'ZOCO MARCO (MI)',
#  'BEZZONE CAMILLA (CN)',
#  'ROSSINI LORENZO (NO)',
#  'DENTELLI GIACOMO (AL)',
#  'GUGLIELMI LORENZO (NO)',
#  'MORLINO LUCA (NO)',
#  'COLOMBO RICCARDO (VA)',
#  'BANFI FABIO (MI)',
#  'BORTOLAMI JULIAN (MI)',
#  'BALLATORE FEDERICO (UD)',
#  'BATTISTUTTA LUCA (GO)',
#  "DONA' ALBERTO (PD)",
#  'BORDIN GRETA (MB)',
#  'CASTELLANI CESARE (CO)',
#  'MILANI LORENZO (CO)',
#  "BORGHI PELIZZONI IVAN MOSE' (MB)",
#  'DI SCIUVA ROMINA EVELIN (CO)',
#  'LONGONI DANIELE (MB)',
#  'ROSSO RICCARDO (PD)',
#  'PISANI ZENO (FI)',
#  'BASILE SAMUELE (SR)',
#  'LIBERTANI GIOELE ANGELO (VE)',
#  'VENDRAMIN JACOPO (VE)',
#  "BERTON NICOLO' (TV)",
#  'COLOMBO EMMA (VA)',
#  'SAVORGNANO AMBRA (UD)',
#  'MASOTTI VANESSA (UD)',
#  'MONTAGNER MARTINA (PN)',
#  'MURRO CAMILLA (PN)',
#  'PETRIS CARLOTTA (PN)',
#  'MONTAGNESE CATERINA (UD)',
#  'MASOTTI MARCO (UD)',
#  'CORNELLA DANIEL (BZ)',
#  'LEONI DANIELE (BZ)',
#  'PICCIONE LEONARDO (RM)',
#  'VASELLI UMBERTO (LO)',
#  'BERTONCELLI KEVIN (CR)',
#  'CINQUEGRANI GABRIELE (PA)',
#  'BUFFA GIUSEPPE (TP)',
#  'LO IACONO DANIEL (TO)',
#  'BLANC KRISTIAN (AO)',
#  "D'ASERO DAVIDE (TO)",
#  'GARIGLIO ALESSANDRO (TO)',
#  'ACQUAVIVA GREGORIO (TO)',
#  'COCCA EMMA (BS)',
#  'BONASSI ANNA (BS)',
#  'BUSCEMI ERMINIA (PA)',
#  'VOTTERO IRENE (TO)',
#  'RICCIARDI SILVIA (TO)',
#  'TESSARI FRANCESCO (VR)',
#  'FERRARI LUCA (BG)',
#  'SCOTELLARO LUCA (BG)',
#  'CORNALI CRISTIAN (BG)',
#  'MELONI ANDREA (RM)',
#  'PETROLATI MARCO (RM)',
#  'DECIANO MATTIA (RM)',
#  'DOLLAKU GIULIA (RA)',
#  'CABRI SOFIA (MO)',
#  'DOLLAKU NIKOL (RA)',
#  'BOLOGNESI FILIPPO (RN)',
#  'GHIRELLI MATTEO (RA)',
#  'BONDI THOMAS (FC)',
#  'ORSI MARTINA (MO)',
#  'ORSI ALESSIA (MO)',
#  'DI GIROLAMO GINEVRA (LI)',
#  'NESTI MELISSA (LU)',
#  'SACCANI FEDERICO (CR)',
#  'FERRARI SERGIO (MN)',
#  'LOMBARDI GIULIA (MI)',
#  'COSTA STARICCO GIULIA (MB)',
#  'FIORINI EDOARDO (AN)',
#  'BELFIORI ALESSIO (AN)',
#  'ZANELLA GIACOMO (AN)',
#  'COSTANTINI EDOARDO (AN)',
#  'LANCIONI TEO (AN)',
#  'MINESTRINI THOMAS (AN)',
#  'FERRARI RUBEN (BG)',
#  'ARNOLDI MATTIA (BG)',
#  'BERSANI FABIO (PC)',
#  'SPOTTI MATTIA (PR)',
#  'BANDINI FILIPPO (RA)',
#  'CHIODARELLI LORENZO (RA)',
#  "ASTARA NICCOLO' (RA)",
#  'SISTI MATTIA (FE)',
#  'RANIERI MATTEO (FC)',
#  'PAGANELLI MATTEO (RA)',
#  'MORICONI LORENZO (RA)',
#  'SCARPELLI CHRISTIAN (RA)',
#  'DAHANI YOUSSEF (PU)',
#  'PICCIOLI KEVIN (PU)',
#  'NICOLOSO LUCA (PU)',
#  'BUSCAGLIA TOMMASO (PU)',
#  'CAPODARCA MATTEO (FI)',
#  'PASIN GIOVANNI (VI)',
#  'BENOZZATO RICCARDO (VI)',
#  'BERNARDELE GIOVANNI (VI)',
#  'GRIMALDI LEONARDO (MC)',
#  'GIONFRIDDO GABRIELE (SR)',
#  'BORDIERI GABRIELE (SR)',
#  'SCIARRA GIUSEPPE (nan)',
#  'PASCARELLA MICHELE (CE)',
#  'DI LAURO GIOVANNI (SA)',
#  'MATRONE GENNARO (nan)',
#  'FERRARO LORENZO (RM)',
#  'PARIS BRIAN (FR)',
#  'GRAZIANI GIANMARIA (FR)',
#  'CICERONI VALERIO (RI)',
#  'DE LAURENTIIS ELENA (CH)',
#  'INVERNIZZI VIOLA (CR)',
#  'LONGO RICCARDO (C)',
#  'MEZZASALMA MASSIMO (LI)',
#  'MATTEOLI FRANCESCO (FI)',
#  'GRILLO GIULIA (TR)',
#  'LONGARI VITTORIO (PG)',
#  'LODOVISI LORENZO (PG)',
#  'CALDERINI GIULIA (PG)',
#  'PARRIGI FILIPPO (PG)',
#  'CORNACCHINI FRANCESCO (PG)',
#  'DOLCI TOMMASO (TR)',
#  'MEAZZINI TOMMASO (PG)',
#  'GENNA FRANCESCA (PD)',
#  'ALTEA MARGHERITA (PG)',
#  'SERANGELI GIACOMO (TR)',
#  'VEDOVELLI CHRISTIAN (TN)',
#  'PALTRINIERI MATTEO (MO)',
#  'GILENO DAVIDE (MB)',
#  'COLELLA FILIPPO (MB)',
#  'TREVISAN SIRIA (VE)',
#  'SANARINI LINDA (PD)',
#  'CENCI MATILDE (VI)',
#  'SANARINI MATTEO (PD)',
#  'MAGGIONI MATTEO (LC)',
#  'GEPPI ELENA (LI)',
#  'CAMPAGNOLO ILARY (VI)',
#  'MILESI ALESSIA (BG)',
#  'TASSI EDOARDO (MO)',
#  'BONGIORNI MATTEO (PC)',
#  'PALPI CAMILLO (PC)',
#  'DE ROSA ALESSANDRO (MB)',
#  'DE VECCHI MARTINA (BG)',
#  'RONCHI CARLOTTA (MB)',
#  'PERUTA SARA (BG)',
#  'LIMONTA GIULIA (BG)',
#  'BELOTTI MISIA (BG)',
#  'ZAMBELLI GIULIA (BG)',
#  'CESARO ROBERTA (CE)',
#  'DELLE FONTANE SOFIA (LT)',
#  'MINICHINO MELANIA (nan)',
#  'ARDUINI FRANCESCO (FR)',
#  'FERRANTE DAMIANO (RM)',
#  'GREGORI MARCO (PC)',
#  'BELVEDERE NICOLA (PD)',
#  'MIGHELI MARCO (FI)',
#  'LUCI LORENZO (FI)',
#  'AGNINI EDOARDO (LU)',
#  'MIGHELI MANUELE GEROLAMO (FI)',
#  'ZANNONI SERENA (RE)',
#  'MANFREDI LEONARDO (RE)',
#  'CASUBOLO GIULIA (RE)',
#  'MASI AURORA (FI)',
#  'FRANCESCHINI EMMA (LI)',
#  'BERNI NICOLETTA (FI)']

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_23235/491006541.py in <module>
# ----> 1 [f"{a:s} ({b:s})" for (a,b) in zip(nome, prov)]
#
# /tmp/ipykernel_23235/491006541.py in <listcomp>(.0)
# ----> 1 [f"{a:s} ({b:s})" for (a,b) in zip(nome, prov)]
#
# ValueError: Unknown format code 's' for object of type 'float'

# %%
table
# Out:
#      Ord  Dors       UCI Id  Licenza        Cognome Nome  \
# 0      1     5  10031079992  A015685       CONTI MARTINA
# 1      2    10  10030852044  A004455       DONATI FLAVIO
# 2      3    11  10065364947  A131741      SIGNORINI LUCA
# 3      4    25  10059762993  A124674  CECCARELLO LORENZO
# 4      5    53  10075622493  A132895   QUAGLIO CHRISTIAN
# ..   ...   ...          ...      ...                 ...
# 253  254     2  10053845185  A095324   MANFREDI LEONARDO
# 254  255     2  10081929113  A154905     CASUBOLO GIULIA
# 255  256    30  10032604815  A063827         MASI AURORA
# 256  257    46  10031017146  A013010   FRANCESCHINI EMMA
# 257  258    47  10031995028  A048056     BERNI NICOLETTA
#
#                           Società
# 0     A. D.PED. AZZURRO.RINASCITA
# 1     A. D.PED. AZZURRO.RINASCITA
# 2     A. D.PED. AZZURRO.RINASCITA
# 3                A.C.D. MONSELICE
# 4                A.C.D. MONSELICE
# ..                            ...
# 253  XPC BELTRAMI TSA COOPERATORI
# 254  XPC BELTRAMI TSA COOPERATORI
# 255     ZHIRAF GUERCIOTTI TOSCANO
# 256     ZHIRAF GUERCIOTTI TOSCANO
# 257     ZHIRAF GUERCIOTTI TOSCANO
#
# [258 rows x 6 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_23235/2579748250.py in <module>
# ----> 1 table = df[["DorsaleNumero", "CodiceUci", "CodiceFCI", "NomeTesserato", "NomeSocieta"]]
#       2 N     = len(table)
#       3 ord   = np.arange(1,N+1)
#       4 table.insert(0, "Ord", ord)
#       5
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5780             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5781
# -> 5782         self._raise_if_missing(keyarr, indexer, axis_name)
#    5783
#    5784         keyarr = self.take(indexer)
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5840                 if use_interval_msg:
#    5841                     key = list(key)
# -> 5842                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5843
#    5844             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['DorsaleNumero', 'CodiceUci', 'CodiceFCI', 'NomeTesserato',\n       'NomeSocieta'],\n      dtype='object')] are in the [columns]"

# %%
table
# Out:
#      DorsaleNumero    CodiceUci CodiceFCI       NomeTesserato  \
# 0                5  10031079992   A015685       CONTI MARTINA
# 1               10  10030852044   A004455       DONATI FLAVIO
# 2               11  10065364947   A131741      SIGNORINI LUCA
# 3               25  10059762993   A124674  CECCARELLO LORENZO
# 4               53  10075622493   A132895   QUAGLIO CHRISTIAN
# ..             ...          ...       ...                 ...
# 253              2  10053845185   A095324   MANFREDI LEONARDO
# 254              2  10081929113   A154905     CASUBOLO GIULIA
# 255             30  10032604815   A063827         MASI AURORA
# 256             46  10031017146   A013010   FRANCESCHINI EMMA
# 257             47  10031995028   A048056     BERNI NICOLETTA
#
#                       NomeSocieta
# 0     A. D.PED. AZZURRO.RINASCITA
# 1     A. D.PED. AZZURRO.RINASCITA
# 2     A. D.PED. AZZURRO.RINASCITA
# 3                A.C.D. MONSELICE
# 4                A.C.D. MONSELICE
# ..                            ...
# 253  XPC BELTRAMI TSA COOPERATORI
# 254  XPC BELTRAMI TSA COOPERATORI
# 255     ZHIRAF GUERCIOTTI TOSCANO
# 256     ZHIRAF GUERCIOTTI TOSCANO
# 257     ZHIRAF GUERCIOTTI TOSCANO
#
# [258 rows x 5 columns]

# %%
table
# Out:
#      DorsaleNumero       NomeTesserato CodiceFCI Categoria    CodiceUci  \
# 0                5       CONTI MARTINA   A015685        DA  10031079992
# 1               10       DONATI FLAVIO   A004455        AL  10030852044
# 2               11      SIGNORINI LUCA   A131741        AL  10065364947
# 3               25  CECCARELLO LORENZO   A124674        ES  10059762993
# 4               53   QUAGLIO CHRISTIAN   A132895        AL  10075622493
# ..             ...                 ...       ...       ...          ...
# 253              2   MANFREDI LEONARDO   A095324        ES  10053845185
# 254              2     CASUBOLO GIULIA   A154905        DA  10081929113
# 255             30         MASI AURORA   A063827        ED  10032604815
# 256             46   FRANCESCHINI EMMA   A013010        DA  10031017146
# 257             47     BERNI NICOLETTA   A048056        DA  10031995028
#
#     DataNascita                   NomeSocieta CodiceSocieta  \
# 0    12/01/2007   A. D.PED. AZZURRO.RINASCITA       07P0798
# 1    11/04/2007   A. D.PED. AZZURRO.RINASCITA       07P0798
# 2    11/10/2007   A. D.PED. AZZURRO.RINASCITA       07P0798
# 3    29/06/2009              A.C.D. MONSELICE       03X0144
# 4    09/10/2007              A.C.D. MONSELICE       03X0144
# ..          ...                           ...           ...
# 253  11/05/2010  XPC BELTRAMI TSA COOPERATORI       07F0103
# 254  21/07/2008  XPC BELTRAMI TSA COOPERATORI       07F0103
# 255  05/12/2009     ZHIRAF GUERCIOTTI TOSCANO       08H3021
# 256  17/01/2007     ZHIRAF GUERCIOTTI TOSCANO       08H3021
# 257  16/10/2008     ZHIRAF GUERCIOTTI TOSCANO       08H3021
#
#                        Note       Cognome       Nome Provincia
# 0            Iscrizione CR.         CONTI    MARTINA        RA
# 1            Iscrizione CR.        DONATI     FLAVIO        RA
# 2            Iscrizione CR.     SIGNORINI       LUCA        RA
# 3            Iscrizione CR.    CECCARELLO    LORENZO        PD
# 4            Iscrizione CR.       QUAGLIO  CHRISTIAN        PD
# ..                      ...           ...        ...       ...
# 253          Iscrizione CR.      MANFREDI   LEONARDO        RE
# 254          Iscrizione CR.      CASUBOLO     GIULIA        RE
# 255  Iscrizione CR. TOSCANA          MASI     AURORA        FI
# 256  Iscrizione CR. TOSCANA  FRANCESCHINI       EMMA        LI
# 257  Iscrizione CR. TOSCANA         BERNI  NICOLETTA        FI
#
# [258 rows x 12 columns]

# %%
df
# Out:
#                                        NomeGara  DorsaleNumero  \
# 0    CAMPIONATI ITALIANI PISTA 2023 - GIOVANILI              5
# 1    CAMPIONATI ITALIANI PISTA 2023 - GIOVANILI             10
# 2    CAMPIONATI ITALIANI PISTA 2023 - GIOVANILI             11
# 3    CAMPIONATI ITALIANI PISTA 2023 - GIOVANILI             25
# 4    CAMPIONATI ITALIANI PISTA 2023 - GIOVANILI             53
# ..                                          ...            ...
# 253  CAMPIONATI ITALIANI PISTA 2023 - GIOVANILI              2
# 254  CAMPIONATI ITALIANI PISTA 2023 - GIOVANILI              2
# 255  CAMPIONATI ITALIANI PISTA 2023 - GIOVANILI             30
# 256  CAMPIONATI ITALIANI PISTA 2023 - GIOVANILI             46
# 257  CAMPIONATI ITALIANI PISTA 2023 - GIOVANILI             47
#
#           NomeTesserato CodiceFCI Categoria    CodiceUci Nazionalità  \
# 0         CONTI MARTINA   A015685        DA  10031079992         ITA
# 1         DONATI FLAVIO   A004455        AL  10030852044         ITA
# 2        SIGNORINI LUCA   A131741        AL  10065364947         ITA
# 3    CECCARELLO LORENZO   A124674        ES  10059762993         ITA
# 4     QUAGLIO CHRISTIAN   A132895        AL  10075622493         ITA
# ..                  ...       ...       ...          ...         ...
# 253   MANFREDI LEONARDO   A095324        ES  10053845185         ITA
# 254     CASUBOLO GIULIA   A154905        DA  10081929113         ITA
# 255         MASI AURORA   A063827        ED  10032604815         ITA
# 256   FRANCESCHINI EMMA   A013010        DA  10031017146         ITA
# 257     BERNI NICOLETTA   A048056        DA  10031995028         ITA
#
#     DataNascita                   NomeSocieta CodiceSocieta     CodiceFiscale  \
# 0    12/01/2007   A. D.PED. AZZURRO.RINASCITA       07P0798  CNTMTN07A52H199X
# 1    11/04/2007   A. D.PED. AZZURRO.RINASCITA       07P0798  DNTFLV07D11H199N
# 2    11/10/2007   A. D.PED. AZZURRO.RINASCITA       07P0798  SGNLCU07R11H199Y
# 3    29/06/2009              A.C.D. MONSELICE       03X0144  CCCLNZ09H29A001P
# 4    09/10/2007              A.C.D. MONSELICE       03X0144  QGLCRS07R09F382C
# ..          ...                           ...           ...               ...
# 253  11/05/2010  XPC BELTRAMI TSA COOPERATORI       07F0103  MNFLRD10E11H223T
# 254  21/07/2008  XPC BELTRAMI TSA COOPERATORI       07F0103  CSBGLI08L61F463J
# 255  05/12/2009     ZHIRAF GUERCIOTTI TOSCANO       08H3021  MSARRA09T45A564B
# 256  17/01/2007     ZHIRAF GUERCIOTTI TOSCANO       08H3021  FRNMME07A57C415K
# 257  16/10/2008     ZHIRAF GUERCIOTTI TOSCANO       08H3021  BRNNLT08R56D612E
#
#     Sesso                    Note       Cognome       Nome Riserva  \
# 0       F          Iscrizione CR.         CONTI    MARTINA      NO
# 1       M          Iscrizione CR.        DONATI     FLAVIO      NO
# 2       M          Iscrizione CR.     SIGNORINI       LUCA      NO
# 3       M          Iscrizione CR.    CECCARELLO    LORENZO      NO
# 4       M          Iscrizione CR.       QUAGLIO  CHRISTIAN      NO
# ..    ...                     ...           ...        ...     ...
# 253     M          Iscrizione CR.      MANFREDI   LEONARDO      NO
# 254     F          Iscrizione CR.      CASUBOLO     GIULIA      NO
# 255     F  Iscrizione CR. TOSCANA          MASI     AURORA      NO
# 256     F  Iscrizione CR. TOSCANA  FRANCESCHINI       EMMA      NO
# 257     F  Iscrizione CR. TOSCANA         BERNI  NICOLETTA      NO
#
#     Scadenza Certificato Provincia
# 0             2024-05-14        RA
# 1             2023-09-18        RA
# 2             2023-10-14        RA
# 3             2024-01-19        PD
# 4             2023-09-21        PD
# ..                   ...       ...
# 253           2023-12-05        RE
# 254           2024-01-26        RE
# 255           2024-01-09        FI
# 256           2024-02-22        LI
# 257           2024-02-09        FI
#
# [258 rows x 18 columns]

# %%
table = df.to_html(index=False).replace('table border="1" class="dataframe"', 'table border="1" cellpadding="5" cellspacing="0" style="background-color: #F0F5FF; border-style: ridge; color: #4040C0" width="100%"').replace('<td>', '<td width=100>')
table
# Out:
# '<table border="1" cellpadding="5" cellspacing="0" style="background-color: #F0F5FF; border-style: ridge; color: #4040C0" width="100%">\n  <thead>\n    <tr style="text-align: right;">\n      <th>Nome</th>\n      <th>Punteggio</th>\n      <th>Posizione</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td width=100>John Doe</td>\n      <td width=100>85</td>\n      <td width=100>1</td>\n    </tr>\n    <tr>\n      <td width=100>Jane Smith</td>\n      <td width=100>92</td>\n      <td width=100>2</td>\n    </tr>\n    <tr>\n      <td width=100>Mike Johnson</td>\n      <td width=100>78</td>\n      <td width=100>3</td>\n    </tr>\n  </tbody>\n</table>'

# %%
from pyfpdf import FPDF, HTMLMixin
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_23235/3691310288.py in <module>
# ----> 1 from pyfpdf import FPDF, HTMLMixin
#
# ModuleNotFoundError: No module named 'pyfpdf'

# %%
table.replace('<table border="1"', '<table border="1" width="100%"')
# Out:
# '<table border="1" width="100%" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Nome</th>\n      <th>Punteggio</th>\n      <th>Posizione</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>John Doe</td>\n      <td>85</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Jane Smith</td>\n      <td>92</td>\n      <td>2</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Mike Johnson</td>\n      <td>78</td>\n      <td>3</td>\n    </tr>\n  </tbody>\n</table>'

# %%
table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Nome</th>\n      <th>Punteggio</th>\n      <th>Posizione</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>John Doe</td>\n      <td>85</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Jane Smith</td>\n      <td>92</td>\n      <td>2</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Mike Johnson</td>\n      <td>78</td>\n      <td>3</td>\n    </tr>\n  </tbody>\n</table>'

# %%
PDF
