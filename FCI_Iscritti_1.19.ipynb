# %% [markdown]
# # Controlla iscrizioni
# Script that performs checks that FCI/ksport should do...

# %%
import pandas as pd

dir_iscrivi = "/home/nic/al/commissaire/data/Iscritti_165801.xls"

# Load dataset
df   = pd.read_excel(dir_iscrivi)
Nall = len(df)

# Name, and ID of the competiton
idGara, nomeGara = df["IdGara"][0],df["NomeGara"][0]
df = df.drop(columns=["IdGara", "NomeGara"])

# Categories of the enrolled riders
# cat_counts_all = df['Categoria'].value_counts()
cat_counts        = df['Categoria'][(df["Riserva"]=="NO") & (~df['Categoria'].isin(['TA2', 'TA3'])) ].value_counts()
cat_counts_ris    = df['Categoria'][(df["Riserva"]=="SI") & (~df['Categoria'].isin(['TA2', 'TA3'])) ].value_counts()
cat_table         = pd.merge(cat_counts, cat_counts_ris, left_index=True, right_index=True, how='outer')
cat_table.columns = ['', 'Ris']


# Remove teams that put leading spaces as their name, and re-sort
df['NomeSocieta'] = df['NomeSocieta'].str.lstrip()
df = df.sort_values('NomeSocieta')

# Group by teams
df_teams    = df.groupby("NomeSocieta")
teams_names = df_teams.groups.keys()
Nteams      = len(teams_names)



# teams_names = [s.replace(" ", "") for s in teams_names]

print("#"*(11+len(nomeGara)))
print(" {:d} - {:s}".format(idGara, nomeGara))
print("#"*(11+len(nomeGara))+"\n")
print("Dataset length: {:d} ({:d} teams)\n".format(Nall,Nteams))

print(cat_table)
print("TOT  {:d}   {:d}".format(cat_counts.sum(),cat_counts_ris.sum()))
# result.colums = ["e", "ris"]
# Out:
# #####################################
#  165801 - TROFEO CITTA' DI NONANTOLA
# #####################################
#
# Dataset length: 253 (30 teams)
#
#           Ris
# UN   165   28
# EL    30   12
# REG    8    3
# TOT  203   43

# %% [markdown]
# ### Check 1 - REG
# Riders with ("REG": registrazione atleta estero) must be authorised by the STF of the national federation.
# FCI: the authorizations are uploaded on the GARS system.

# %%
pd.Series([cat_counts, cat_counts_ris])
df["year_of_birth"] = pd.to_numeric(df["DataNascita"].str[-4:])
df["age"] = 2023 - df["year_of_birth"]
print(df[["NomeTesserato", "Categoria", "age", "NomeSocieta", "Riserva"]][df["Categoria"]=="REG"].to_markdown())
# Out:
# |     | NomeTesserato                 | Categoria   |   age | NomeSocieta                         | Riserva   |
# |----:|:------------------------------|:------------|------:|:------------------------------------|:----------|
# |  83 | HOEKS DAAN EDUARD JAN         | REG         |    23 | GS MALTINTI LAMP. BANCA CAMBIANO    | NO        |
# |  96 | GOMEZ JARAMILLO NICOLAS DAVID | REG         |    23 | HOPPLA'-PETROLI FIRENZE-DON CAMILLO | NO        |
# |  97 | DE LISI NICOLO'               | REG         |    22 | HOPPLA'-PETROLI FIRENZE-DON CAMILLO | SI        |
# | 112 | SIMON SEMEN                   | REG         |    19 | LINEAOROBIKE AVEZZANO               | NO        |
# | 124 | HANNAY TYLER                  | REG         |    20 | MASTROMARCO SENSI FC NIBALI         | SI        |
# | 140 | TUR MIKITA                    | REG         |    20 | ONEC TEAM                           | NO        |
# | 170 | BALAJ MATEO                   | REG         |    19 | PRO.GI.T. CYCLING TEAM              | NO        |
# | 190 | BIDWELL ADAM                  | REG         |    20 | SIAS RIME                           | NO        |
# | 208 | DI DOMENICO DANIEL CRISTIAN   | REG         |    22 | SOLME - OLMO                        | SI        |
# | 207 | HRENKO NORBERT                | REG         |    22 | SOLME - OLMO                        | NO        |
# | 230 | MORTENSEN OLIVER              | REG         |    19 | U.C TREVIGIANI ENERGIAPURA MARCHIOL | NO        |

# %% [markdown]
# ### Check 2 - Age (& enrolled team directors)
# In EL/U23 competition maximum age is 27 yr for italian riders and 25 yr for foreigners.

# %%
older_25 = df["age"] >= 27

if sum(older_25) > 0:
    print(df[["NomeTesserato", "Categoria", "age", "NomeSocieta", "Nazionalità"]][older_25].to_markdown())
# Out:
# |     | NomeTesserato     | Categoria   |   age | NomeSocieta                         | Nazionalità   |
# |----:|:------------------|:------------|------:|:------------------------------------|:--------------|
# |  28 | AMICI ALESSANDRO  | EL          |    27 | A.S.D. CATTOLI ANDREA               | ITA           |
# |  40 | CASADEI MASSIMO   | TA3         |    69 | ARVEDI CYCLING ASD                  | ITA           |
# |  37 | ZANETTI GAETANO   | TA3         |    48 | ARVEDI CYCLING ASD                  | ITA           |
# | 105 | BERGAMANTE FRANCO | TA3         |    69 | LINEAOROBIKE AVEZZANO               | ITA           |
# | 158 | LUDDI ALFREDO     | TA3         |    74 | PARKPRE IKI SPORT                   | ITA           |
# | 188 | CALOSSO DANIELE   | TA3         |    35 | SIAS RIME                           | ITA           |
# | 217 | LAMPUGNANI FRANCO | TA3         |    59 | U.C TREVIGIANI ENERGIAPURA MARCHIOL | ITA           |

# %% [markdown]
# ### Check 3 - Number of riders enrolled per team
# In 1.19 competitions the maximum number of riders per team is set to **10** (and 50% reserves). This number becomes **9** if there are there are only two competitions (reg/naz/int) and the organizing team can have +2 riders. If the total number of enrolled riders is less than 80, each team may have up to 12 riders. From this computation first year U23 category riders are excluded.

# %%
# Loop through each team and check the maximum number of riders

# Define the maximum number of riders per team based on the competition rules
max_riders                  = 10
# Define the maximum number of riders per team if there are only two competitions
max_riders_two_competitions = 9
# Define the maximum number of riders per team if the total enrolled riders is less than 80
max_riders_less_than_80     = 12
# Define the minimum year for eligibility based on the age limit of 18
min_year                    = 2003

Nlimite = max_riders_two_competitions

df_teams1 = df_teams[["NomeTesserato", "Categoria", "year_of_birth", "NomeSocieta", "Riserva"]]

i = 0
for team, data in df_teams1:
    i += 1
    print("\n(", i, ")  ############",team,"############")
    data       = data[~data['Categoria'].isin(['TA2', 'TA3'])]
    Niscritti  = len(data[data["Riserva"]=="NO"])
    Nriserve   = len(data[data["Riserva"]=="SI"])
    print("Iscritti:   {:d}".format(Niscritti))
    if Nriserve > Nlimite:
        print("            ^ WARNING")
    print("Riserve:    {:d}".format(Nriserve))
    if Nriserve > int(0.5*Niscritti):
        print("            ^ WARNING")
    data       = data.sort_values("year_of_birth").sort_values('Riserva')

    data['year_of_birth'] = data['year_of_birth'].astype(str)
    data.loc[data['year_of_birth'] == '2004', 'year_of_birth'] = '*2004'

    data.index =  pd.RangeIndex(start=1, stop=len(data)+1)
    # data.reset_index(drop=True, inplace=True)
    print(data.to_markdown())


    # eligible_riders = data[data['year_of_birth'] < min_year]
    # num_eligible_riders = len(eligible_riders)
    # if num_riders < 80:
    #     max_riders_team = max_riders_less_than_80
    # elif num_riders >= 80 and len(data[data['year_of_birth'] >= min_year]) > 0:
    #     max_riders_team = max_riders_two_competitions
    # else:
    #     max_riders_team = max_riders
    # if num_eligible_riders > max_riders_team:
    #     print(f'Team {team} has {num_eligible_riders} eligible riders, exceeding the maximum of {max_riders_team}')
    # else:
    #     print(f'Team {team} has {num_eligible_riders} eligible riders within the maximum of {max_riders_team}')
# Out:
# ( 1 )  ############ A.R. Monex Pro Cycling Team ############
# Iscritti:   1
# Riserve:    0
# |    | NomeTesserato   | Categoria   | year_of_birth   | NomeSocieta                 | Riserva   |
# |---:|:----------------|:------------|:----------------|:----------------------------|:----------|
# |  1 | SCARPONI LUCA   | UN          | *2004           | A.R. Monex Pro Cycling Team | NO        |
#
# ( 2 )  ############ A.S.D. ARIES CYCLING ############
# Iscritti:   7
# Riserve:    0
# |    | NomeTesserato       | Categoria   | year_of_birth   | NomeSocieta          | Riserva   |
# |---:|:--------------------|:------------|:----------------|:---------------------|:----------|
# |  1 | SALVALAGGIO GIACOMO | UN          | 2001            | A.S.D. ARIES CYCLING | NO        |
# |  2 | PELLICARI MATTEO    | UN          | 2001            | A.S.D. ARIES CYCLING | NO        |
# |  3 | GUARNIERI FILIPPO   | UN          | 2001            | A.S.D. ARIES CYCLING | NO        |
# |  4 | VECCHI LORENZO      | UN          | 2001            | A.S.D. ARIES CYCLING | NO        |
# |  5 | CHEULA ANDREA       | UN          | 2003            | A.S.D. ARIES CYCLING | NO        |
# |  6 | LONARDI FRANCESCO   | UN          | *2004           | A.S.D. ARIES CYCLING | NO        |
# |  7 | CARRÒ SAMUELE       | UN          | *2004           | A.S.D. ARIES CYCLING | NO        |
#
# ( 3 )  ############ A.S.D. CATTOLI ANDREA ############
# Iscritti:   8
# Riserve:    0
# |    | NomeTesserato           | Categoria   | year_of_birth   | NomeSocieta           | Riserva   |
# |---:|:------------------------|:------------|:----------------|:----------------------|:----------|
# |  1 | AMICI ALESSANDRO        | EL          | 1996            | A.S.D. CATTOLI ANDREA | NO        |
# |  2 | POLIDORI STEFANO        | EL          | 2000            | A.S.D. CATTOLI ANDREA | NO        |
# |  3 | LENTI LUCA              | UN          | 2001            | A.S.D. CATTOLI ANDREA | NO        |
# |  4 | SARTI MARCO             | UN          | 2001            | A.S.D. CATTOLI ANDREA | NO        |
# |  5 | SANTI O DE SANTI FLAVIO | UN          | 2002            | A.S.D. CATTOLI ANDREA | NO        |
# |  6 | ANGELI VALENTINO        | UN          | 2003            | A.S.D. CATTOLI ANDREA | NO        |
# | 11 | HANNAY TYLER           | REG         | 2003            | MASTROMARCO SENSI FC NIBALI | SI        |
# | 12 | BENNATI MATTEO         | UN          | *2004           | MASTROMARCO SENSI FC NIBALI | SI        |
#
# ( 16 )  ############ MG.K VIS - COLORS FOR PEACE ############
# Iscritti:   6
# Riserve:    0
# |    | NomeTesserato    | Categoria   | year_of_birth   | NomeSocieta                 | Riserva   |
# |---:|:-----------------|:------------|:----------------|:----------------------------|:----------|
# |  1 | SPADA ANTONIO    | UN          | 2003            | MG.K VIS - COLORS FOR PEACE | NO        |
# |  2 | GAVILLI LAPO     | UN          | 2003            | MG.K VIS - COLORS FOR PEACE | NO        |
# |  3 | DI FELICE MATTIA | UN          | *2004           | MG.K VIS - COLORS FOR PEACE | NO        |
# |  4 | MEARELLI ANDREA  | UN          | *2004           | MG.K VIS - COLORS FOR PEACE | NO        |
# |  5 | CASINI DAVIDE    | UN          | *2004           | MG.K VIS - COLORS FOR PEACE | NO        |
# |  6 | SILENZI ANTHONI  | UN          | *2004           | MG.K VIS - COLORS FOR PEACE | NO        |
#
# ( 17 )  ############ ONEC TEAM ############
# Iscritti:   8
# Riserve:    2
# |    | NomeTesserato      | Categoria   | year_of_birth   | NomeSocieta   | Riserva   |
# |---:|:-------------------|:------------|:----------------|:--------------|:----------|
# |  1 | COLNAGHI ANDREA    | EL          | 1997            | ONEC TEAM     | NO        |
# |  2 | GUGLIELMI RICCARDO | EL          | 2000            | ONEC TEAM     | NO        |
# |  3 | ALLODI MATTEO      | UN          | 2001            | ONEC TEAM     | NO        |
# |  4 | AMATI GABRIELE     | UN          | 2001            | ONEC TEAM     | NO        |
# |  5 | TUR MIKITA         | REG         | 2003            | ONEC TEAM     | NO        |
# |  6 | ALLEGRI VALERIO    | UN          | 2003            | ONEC TEAM     | NO        |
# |  7 | TERZI MATTEO       | UN          | 2003            | ONEC TEAM     | NO        |
# |  8 | RULLI EDOARDO      | UN          | *2004           | ONEC TEAM     | NO        |
# |  9 | ZANINELLI STEFANO  | UN          | 2002            | ONEC TEAM     | SI        |
# | 10 | ZATTIN LUCA        | UN          | *2004           | ONEC TEAM     | SI        |
#
# ( 18 )  ############ OVERALL TRE COLLI CYCLING TEAM ############
# Iscritti:   9
# Riserve:    5
#             ^ WARNING
# |    | NomeTesserato          | Categoria   | year_of_birth   | NomeSocieta                    | Riserva   |
# |---:|:-----------------------|:------------|:----------------|:-------------------------------|:----------|
# |  1 | BELLONI MASSIMILIANO   | UN          | 2001            | OVERALL TRE COLLI CYCLING TEAM | NO        |
# |  2 | DAVARIAS IOANNIS       | UN          | 2002            | OVERALL TRE COLLI CYCLING TEAM | NO        |
# |  3 | GIANELLO DANIEL        | UN          | 2002            | OVERALL TRE COLLI CYCLING TEAM | NO        |
# |  4 | MORELLO GIOVANNI MARIA | UN          | 2003            | OVERALL TRE COLLI CYCLING TEAM | NO        |
# |  5 | DANIEL TOMMASO         | UN          | 2003            | OVERALL TRE COLLI CYCLING TEAM | NO        |
# |  6 | BELLONI LUCA           | UN          | 2003            | OVERALL TRE COLLI CYCLING TEAM | NO        |
# |  7 | PONTI NICOLO'          | UN          | 2003            | OVERALL TRE COLLI CYCLING TEAM | NO        |
# |  8 | DI PAOLO MATTEO        | UN          | *2004           | OVERALL TRE COLLI CYCLING TEAM | NO        |
# |  9 | ROSA BRUSIN SAMUELE    | UN          | *2004           | OVERALL TRE COLLI CYCLING TEAM | NO        |
# | 10 | CAVALLO LUCA           | EL          | 1999            | OVERALL TRE COLLI CYCLING TEAM | SI        |
# | 11 | SASSO MATTEO           | EL          | 2000            | OVERALL TRE COLLI CYCLING TEAM | SI        |
# | 12 | GIANI LEONARDO         | EL          | 2000            | OVERALL TRE COLLI CYCLING TEAM | SI        |
# | 13 | ANTONETTI ARONNE       | UN          | 2002            | OVERALL TRE COLLI CYCLING TEAM | SI        |
# | 14 | GRIMALDI RICCARDO      | UN          | *2004           | OVERALL TRE COLLI CYCLING TEAM | SI        |
#
# ( 19 )  ############ PARKPRE IKI SPORT ############
# Iscritti:   9
# Riserve:    1
# |    | NomeTesserato         | Categoria   |   year_of_birth | NomeSocieta       | Riserva   |
# |---:|:----------------------|:------------|----------------:|:------------------|:----------|
# |  1 | DEMIRI MIKEL          | EL          |            2000 | PARKPRE IKI SPORT | NO        |
# |  2 | SALVADORI DARIO       | EL          |            2000 | PARKPRE IKI SPORT | NO        |
# |  3 | MAGALOTTI MATTEO      | UN          |            2001 | PARKPRE IKI SPORT | NO        |
# |  4 | FRANCHINI FRANCESCO   | UN          |            2002 | PARKPRE IKI SPORT | NO        |
# |  5 | MORELLI FILIPPO       | UN          |            2002 | PARKPRE IKI SPORT | NO        |
# |  6 | SALVADORI PIETRO      | UN          |            2002 | PARKPRE IKI SPORT | NO        |
# |  7 | MINISSALE MARCO MARIA | UN          |            2003 | PARKPRE IKI SPORT | NO        |
# |  8 | OLIBONI FRANCESCO     | UN          |            2003 | PARKPRE IKI SPORT | NO        |
# |  9 | COLTELLI EDOARDO      | UN          |            2003 | PARKPRE IKI SPORT | NO        |
# | 10 | BIGALLI SAMUELE       | UN          |            2002 | PARKPRE IKI SPORT | SI        |
#
# ( 20 )  ############ PRO.GI.T. CYCLING TEAM ############
# Iscritti:   5
# Riserve:    0
# |    | NomeTesserato      | Categoria   | year_of_birth   | NomeSocieta            | Riserva   |
# |---:|:-------------------|:------------|:----------------|:-----------------------|:----------|
# |  1 | DAVOLI BRUNO       | EL          | 1999            | PRO.GI.T. CYCLING TEAM | NO        |
# |  2 | DAVOLI KEVIN       | EL          | 1999            | PRO.GI.T. CYCLING TEAM | NO        |
# |  3 | BINETTI FRANCESCO  | UN          | 2001            | PRO.GI.T. CYCLING TEAM | NO        |
# |  4 | VENEZIANO ANTONINO | UN          | 2003            | PRO.GI.T. CYCLING TEAM | NO        |
# |  5 | BALAJ MATEO        | REG         | *2004           | PRO.GI.T. CYCLING TEAM | NO        |
#
# ( 21 )  ############ S.C. VALLE SERIANA - CENE A.S.D. ############
# Iscritti:   7
# Riserve:    3
# |    | NomeTesserato           | Categoria   | year_of_birth   | NomeSocieta                      | Riserva   |
# |---:|:------------------------|:------------|:----------------|:---------------------------------|:----------|
# |  1 | DANIELI ETTORE          | UN          | 2001            | S.C. VALLE SERIANA - CENE A.S.D. | NO        |
# |  2 | BORDOLI NICOLA          | UN          | 2001            | S.C. VALLE SERIANA - CENE A.S.D. | NO        |
# |  3 | BONORA ALESSIO          | UN          | 2003            | S.C. VALLE SERIANA - CENE A.S.D. | NO        |
# |  4 | BORELLA LORENZO         | UN          | 2003            | S.C. VALLE SERIANA - CENE A.S.D. | NO        |
# |  5 | MARTINELLI MIRKO NICOLA | UN          | 2003            | S.C. VALLE SERIANA - CENE A.S.D. | NO        |
# |  6 | GAMBA FRANCESCO         | UN          | *2004           | S.C. VALLE SERIANA - CENE A.S.D. | NO        |
# |  7 | ORI ELIA                | UN          | *2004           | S.C. VALLE SERIANA - CENE A.S.D. | NO        |
# |  8 | GERVASONI FEDERICO      | UN          | 2001            | S.C. VALLE SERIANA - CENE A.S.D. | SI        |
# |  9 | RICCA SAMUELE           | UN          | *2004           | S.C. VALLE SERIANA - CENE A.S.D. | SI        |
# | 10 | FURLAN LUCA             | UN          | *2004           | S.C. VALLE SERIANA - CENE A.S.D. | SI        |
#
# ( 22 )  ############ S.S.D. SANCASCIANESE CICLISMO SRL ############
# Iscritti:   1
# Riserve:    0
# |    | NomeTesserato   | Categoria   | year_of_birth   | NomeSocieta                       | Riserva   |
# |---:|:----------------|:------------|:----------------|:----------------------------------|:----------|
# |  1 | MORONI LEONARDO | UN          | *2004           | S.S.D. SANCASCIANESE CICLISMO SRL | NO        |
#
# ( 23 )  ############ SIAS RIME ############
# Iscritti:   5
# Riserve:    3
#             ^ WARNING
# |    | NomeTesserato     | Categoria   | year_of_birth   | NomeSocieta   | Riserva   |
# |---:|:------------------|:------------|:----------------|:--------------|:----------|
# |  1 | BIDWELL ADAM      | REG         | 2003            | SIAS RIME     | NO        |
# |  2 | AQUILA GIUSEPPE   | UN          | 2003            | SIAS RIME     | NO        |
# |  3 | FRACCARO LORENZO  | UN          | 2003            | SIAS RIME     | NO        |
# |  4 | ROSA LUCA         | UN          | *2004           | SIAS RIME     | NO        |
# |  5 | ANNIBALLI LORENZO | UN          | *2004           | SIAS RIME     | NO        |
# |  6 | PONGILUPPI MATTEO | EL          | 2000            | SIAS RIME     | SI        |
# |  7 | BAGATIN CHRISTIAN | UN          | 2002            | SIAS RIME     | SI        |
# |  8 | PETTITI NICOLO'   | UN          | 2002            | SIAS RIME     | SI        |
#
# ( 24 )  ############ SOLME - OLMO ############
# Iscritti:   9
# Riserve:    9
#             ^ WARNING
# |    | NomeTesserato               | Categoria   | year_of_birth   | NomeSocieta   | Riserva   |
# |---:|:----------------------------|:------------|:----------------|:--------------|:----------|
# |  1 | BAFFI STEFANO               | EL          | 1998            | SOLME - OLMO  | NO        |
# |  2 | GRECO ALESSANDRO            | UN          | 2002            | SOLME - OLMO  | NO        |
# |  3 | FARINATI LORENZO            | UN          | 2002            | SOLME - OLMO  | NO        |
# |  4 | TOLOMIO NICOLO'             | UN          | 2001            | SOLME - OLMO  | NO        |
# |  5 | TREVISOL MARCO              | EL          | 2000            | SOLME - OLMO  | NO        |
# |  6 | HRENKO NORBERT              | REG         | 2001            | SOLME - OLMO  | NO        |
# |  7 | BUDA SIMONE                 | EL          | 1999            | SOLME - OLMO  | NO        |
# |  8 | SPINELLI NICHOLAS           | EL          | 2000            | SOLME - OLMO  | NO        |
# |  9 | CALLEGARO NICOLO'           | UN          | *2004           | SOLME - OLMO  | NO        |
# | 10 | BERZI ANDREA                | EL          | 2000            | SOLME - OLMO  | SI        |
# | 11 | LUCCA SIMONE                | EL          | 2000            | SOLME - OLMO  | SI        |
# | 12 | RUFFIN RICCARDO             | UN          | *2004           | SOLME - OLMO  | SI        |
# | 13 | DI DOMENICO DANIEL CRISTIAN | REG         | 2001            | SOLME - OLMO  | SI        |
# | 14 | FERRARI DAVIDE              | EL          | 1999            | SOLME - OLMO  | SI        |
# | 15 | MENEGALE ELIA               | EL          | 1999            | SOLME - OLMO  | SI        |
# | 16 | FORMICA DANIELE             | UN          | 2002            | SOLME - OLMO  | SI        |
# | 17 | COMIN MAICOL                | UN          | 2002            | SOLME - OLMO  | SI        |
# | 18 | MENGHINI ALESSIO            | UN          | *2004           | SOLME - OLMO  | SI        |
#
# ( 25 )  ############ TEAM CICLI MANINI ############
# Iscritti:   1
# Riserve:    1
#             ^ WARNING
# |    | NomeTesserato    | Categoria   |   year_of_birth | NomeSocieta       | Riserva   |
# |---:|:-----------------|:------------|----------------:|:------------------|:----------|
# |  1 | SPADONI GABRIELE | EL          |            2000 | TEAM CICLI MANINI | NO        |
# |  2 | MARZANI MARCO    | EL          |            2000 | TEAM CICLI MANINI | SI        |
#
# ( 26 )  ############ TEAM MAZZOLA P.G.C. U23 ############
# Iscritti:   6
# Riserve:    0
# |    | NomeTesserato      | Categoria   | year_of_birth   | NomeSocieta             | Riserva   |
# |---:|:-------------------|:------------|:----------------|:------------------------|:----------|
# |  1 | MAZZOLA DANIEL     | EL          | 2000            | TEAM MAZZOLA P.G.C. U23 | NO        |
# |  2 | PENNATI MATTEO     | UN          | 2001            | TEAM MAZZOLA P.G.C. U23 | NO        |
# |  3 | PASSAFIUME FILIPPO | UN          | *2004           | TEAM MAZZOLA P.G.C. U23 | NO        |
# |  4 | MENGA FEDERICO     | UN          | *2004           | TEAM MAZZOLA P.G.C. U23 | NO        |
# |  5 | CARRONI YURI       | UN          | *2004           | TEAM MAZZOLA P.G.C. U23 | NO        |
# |  6 | AUSTONI STEFANO    | UN          | *2004           | TEAM MAZZOLA P.G.C. U23 | NO        |
#
# ( 27 )  ############ U.C TREVIGIANI ENERGIAPURA MARCHIOL ############
# Iscritti:   9
# Riserve:    3
# |    | NomeTesserato           | Categoria   | year_of_birth   | NomeSocieta                         | Riserva   |
# |---:|:------------------------|:------------|:----------------|:------------------------------------|:----------|
# |  1 | POZZA ETTORE            | EL          | 1999            | U.C TREVIGIANI ENERGIAPURA MARCHIOL | NO        |
# |  2 | PRESTI ANDREAS          | UN          | 2001            | U.C TREVIGIANI ENERGIAPURA MARCHIOL | NO        |
# |  3 | PALOMBA MARCO           | UN          | 2002            | U.C TREVIGIANI ENERGIAPURA MARCHIOL | NO        |
# |  4 | LA TERRA PIRRE' SAMUELE | UN          | 2002            | U.C TREVIGIANI ENERGIAPURA MARCHIOL | NO        |
# |  5 | CAO MARCO               | UN          | 2002            | U.C TREVIGIANI ENERGIAPURA MARCHIOL | NO        |
# |  6 | D'ANIELLO IMMANUEL      | UN          | 2002            | U.C TREVIGIANI ENERGIAPURA MARCHIOL | NO        |
# |  7 | CHESINI RICCARDO        | UN          | 2003            | U.C TREVIGIANI ENERGIAPURA MARCHIOL | NO        |
# |  8 | MORTENSEN OLIVER        | REG         | *2004           | U.C TREVIGIANI ENERGIAPURA MARCHIOL | NO        |
# |  9 | CIREDDU IGNAZIO         | UN          | *2004           | U.C TREVIGIANI ENERGIAPURA MARCHIOL | NO        |
# | 10 | DE TOTTO ANDREA         | EL          | 2000            | U.C TREVIGIANI ENERGIAPURA MARCHIOL | SI        |
# | 11 | CAZZOLA GIACOMO         | UN          | 2002            | U.C TREVIGIANI ENERGIAPURA MARCHIOL | SI        |
# | 12 | SPAGNOL LEONARDO        | UN          | *2004           | U.C TREVIGIANI ENERGIAPURA MARCHIOL | SI        |
#
# ( 28 )  ############ U.C. PREGNANA  TEAM SCOUT ASD ############
# Iscritti:   8
# Riserve:    0
# |    | NomeTesserato      | Categoria   |   year_of_birth | NomeSocieta                   | Riserva   |
# |---:|:-------------------|:------------|----------------:|:------------------------------|:----------|
# |  1 | BERTONI LUCA       | EL          |            1998 | U.C. PREGNANA  TEAM SCOUT ASD | NO        |
# |  2 | DE ROBERTIS ENRICO | EL          |            1998 | U.C. PREGNANA  TEAM SCOUT ASD | NO        |
# |  3 | MURLO MATTEO       | EL          |            1998 | U.C. PREGNANA  TEAM SCOUT ASD | NO        |
# |  4 | GALIMBERTI STEFANO | EL          |            1999 | U.C. PREGNANA  TEAM SCOUT ASD | NO        |
# |  5 | RUBINO SAMUELE     | EL          |            2000 | U.C. PREGNANA  TEAM SCOUT ASD | NO        |
# |  6 | RANCILIO MARCO     | UN          |            2001 | U.C. PREGNANA  TEAM SCOUT ASD | NO        |
# |  7 | RIZZI GABRIELE     | UN          |            2001 | U.C. PREGNANA  TEAM SCOUT ASD | NO        |
# |  8 | LOGLI NICOLA       | UN          |            2002 | U.C. PREGNANA  TEAM SCOUT ASD | NO        |
#
# ( 29 )  ############ U.S. VERTEMATESE  A.S.D. ############
# Iscritti:   3
# Riserve:    0
# |    | NomeTesserato    | Categoria   | year_of_birth   | NomeSocieta              | Riserva   |
# |---:|:-----------------|:------------|:----------------|:-------------------------|:----------|
# |  1 | RIZZI MIRKO      | UN          | 2003            | U.S. VERTEMATESE  A.S.D. | NO        |
# |  2 | PERAUDO MASSIMO  | UN          | *2004           | U.S. VERTEMATESE  A.S.D. | NO        |
# |  3 | CONSAGRA SAMUELE | UN          | *2004           | U.S. VERTEMATESE  A.S.D. | NO        |
#
# ( 30 )  ############ XPC BELTRAMI TSA COOPERATORI ############
# Iscritti:   9
# Riserve:    2
# |    | NomeTesserato             | Categoria   | year_of_birth   | NomeSocieta                  | Riserva   |
# |---:|:--------------------------|:------------|:----------------|:-----------------------------|:----------|
# |  1 | GAZZOLA MARCO             | EL          | 1999            | XPC BELTRAMI TSA COOPERATORI | NO        |
# |  2 | MARZARI MATTEO            | UN          | 2002            | XPC BELTRAMI TSA COOPERATORI | NO        |
# |  3 | GABRIELE ANGELO           | UN          | 2002            | XPC BELTRAMI TSA COOPERATORI | NO        |
# |  4 | VENERI RAFFAELE           | UN          | 2002            | XPC BELTRAMI TSA COOPERATORI | NO        |
# |  5 | SOFIA RICCARDO            | UN          | 2002            | XPC BELTRAMI TSA COOPERATORI | NO        |
# |  6 | REDEGHIERI ALESSANDRO     | UN          | 2002            | XPC BELTRAMI TSA COOPERATORI | NO        |
# |  7 | COSTA PELLICCIARI NICOLO' | UN          | 2003            | XPC BELTRAMI TSA COOPERATORI | NO        |
# |  8 | MELEGARI LORENZO          | UN          | 2003            | XPC BELTRAMI TSA COOPERATORI | NO        |
# |  9 | GIBELLINI MATTEO          | UN          | *2004           | XPC BELTRAMI TSA COOPERATORI | NO        |
# | 10 | ZECCHINI SIMONE           | UN          | 2001            | XPC BELTRAMI TSA COOPERATORI | SI        |
# | 11 | BORGHI MATTEO             | UN          | *2004           | XPC BELTRAMI TSA COOPERATORI | SI        |
